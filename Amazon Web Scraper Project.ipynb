# %%
# import libraries

from bs4 import BeautifulSoup
import requests
import time
import datetime

import smtplib

# %%
# connect to website
URL = "https://www.amazon.sg/33-Strategies-War-Robert-Greene/dp/1861979789/ref=sr_1_5?keywords=robert+greene&sr=8-5"

headers =     {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36",
    "X-Amzn-Trace-Id": "Root=1-64ddd16a-00e018881814842675ad2202"}
page = requests.get(URL, headers = headers)

Soup1 = BeautifulSoup(page.content, "html.parser")
Soup2 = BeautifulSoup(Soup1.prettify(),"html.parser")

title = Soup2.find(id='productTitle').get_text()
price = Soup2.find(id='price').get_text()
print(title)
print(price)
# Out:
#             The 33 Strategies Of War
#
#
#                             S$24.30

# %%
price = price.strip()[2:]
title = title.strip()
print (title)
print(price)
# Out:
# The 33 Strategies Of War
# 24.30

# %%
import datetime
Today = datetime.date.today()
print(Today)
# Out:
# 2023-08-17

# %%
import csv
header = ['Title', 'Price','Date']
data = [title,price,Today]
with open('AmazonWebScraperDataset.csv', 'w', newline='', encoding = 'UTF8')as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Admin\AmazonWebScraperDataset.csv')
print(df)
# Out:
#                       Title  Price        Date
# 0  The 33 Strategies Of War   24.3  2023-08-17
# 1  The 33 Strategies Of War   24.3  2023-08-17
# 2  The 33 Strategies Of War   24.3  2023-08-17

# %%
#appending data
with open('AmazonWebScraperDataset.csv', 'at', newline='', encoding = 'UTF8')as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
def check_price():
    URL = "https://www.amazon.sg/33-Strategies-War-Robert-Greene/dp/1861979789/ref=sr_1_5?keywords=robert+greene&sr=8-5"

    headers =     {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36",
    "X-Amzn-Trace-Id": "Root=1-64ddd16a-00e018881814842675ad2202"}
    page = requests.get(URL, headers = headers)

    Soup1 = BeautifulSoup(page.content, "html.parser")
    Soup2 = BeautifulSoup(Soup1.prettify(),"html.parser")

    title = Soup2.find(id='productTitle').get_text()
    price = Soup2.find(id='price').get_text()
    price = price.strip()[2:]
    title = title.strip()
    import datetime
    Today = datetime.date.today()
    print(Today)
    import csv
    header = ['Title', 'Price','Date']
    data = [title,price,Today]
    with open('AmazonWebScraperDataset.csv', 'at', newline='', encoding = 'UTF8')as f:
        writer = csv.writer(f)
        writer.writerow(data)

# %%
while(True):
    check_price()
    time.sleep(5)

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Admin\AmazonWebScraperDataset.csv')
print(df)
# Out:
#                       Title  Price        Date
# 0  The 33 Strategies Of War   24.3  2023-08-17
# 1  The 33 Strategies Of War   24.3  2023-08-17
# 2  The 33 Strategies Of War   24.3  2023-08-17
# 3  The 33 Strategies Of War   24.3  2023-08-17
# 4  The 33 Strategies Of War   24.3  2023-08-17
# 5  The 33 Strategies Of War   24.3  2023-08-17
# 6  The 33 Strategies Of War   24.3  2023-08-17

# %% [markdown]
# This is a webscraper project that scrapes the title and price of the book. If we use this on a product where the price fluctuates pretty often , we can see the difference.
# We can set the timer to run it about one day and it should be pretty functional.
